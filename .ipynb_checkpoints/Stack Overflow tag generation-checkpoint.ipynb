# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
df = pd.read_csv('Tagged.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Id  Score  \
# 0           0  12395950      2
# 1           1  22426350      0
# 2           2  19842160      0
# 3           3  22953000      0
# 4           4  35528560      0
#
#                                                Title  \
# 0       Calling Twain driver from 64 bit application
# 1  Why does variable in struct instance change af...
# 2  dynamically creating text fields lands up in d...
# 3      Javascript in PHP/HTML hiding Div not working
# 4  Design a compareTo that can sort in ascending ...
#
#                                                 Body                    Tags
# 0  <p>I need to call TWAIN API from .NET (C#) app...           c# .net twain
# 1  <p>This is really weird.</p>\n\n<p>I have a st...                c struct
# 2  <p>I'm having issues with the below code,\nwhe...  javascript jquery html
# 3  <p>I am new to coding so be gentle.  I am buil...     javascript php html
# ...

# %%
df.shape
# Out:
# (100000, 6)

# %%
df['Body'][0]
# Out:
# '<p>I need to call TWAIN API from .NET (C#) application compiled for x64 target platform. Are there any advices on 3rd party vendors providing 64 bit twain implementations?</p>\n'

# %%
from collections import Counter
import re
import string

# %%
def clean_text(text): #removes the html tags from the questions
    global Empty
    Empty = ''
    if not isinstance(text,str):
        return text
    return re.sub('<[^>]+>',Empty,text)

# %%
#just checking the correctness
clean_text(df['Body'][0])
# Out:
# 'I need to call TWAIN API from .NET (C#) application compiled for x64 target platform. Are there any advices on 3rd party vendors providing 64 bit twain implementations?\n'

# %%
df['text'] = df['Body'].apply(clean_text).str.lower()

# %%
df['Body'][10]
# Out:
# '<p>I am trying to access a Dynamics NAV 2013 R2 web service from Java. The web service is running and when I enter the URL in the Internet Explorer, I can see the WSDL but first I am prompted for Username and Password. On Wireshark I can see that it uses authentication based on NTLM. Sofar I was only able to open the WSDL from Internet Explorer, when I open it on Firefox, it give me a blank page and no error.</p>\n\n<p>What I am trying to do is to access the Web Service from Java using the wsimport tool, but I am unable to authenticate. I have already created a folder in <code>~/.metro/auth</code> and put the following line in there:</p>\n\n<pre><code>http://userfoobar:passforbar@192.168.0.170:7047//DynamicsNAV71/WS/CRONUS%20AG/Page/PageWithCapitalization\n</code></pre>\n\n<p>and I am trying to access the web page with:</p>\n\n<pre><code>wsimport -d generated -s sources http://@192.168.0.170:7047/DynamicsNAV71/WS/CRONUS%20AG/Page/PageWithCapitalization\n</code></pre>\n\n<p>I always 
# ...

# %%
df['text'][10]
# Out:
# 'i am trying to access a dynamics nav 2013 r2 web service from java. the web service is running and when i enter the url in the internet explorer, i can see the wsdl but first i am prompted for username and password. on wireshark i can see that it uses authentication based on ntlm. sofar i was only able to open the wsdl from internet explorer, when i open it on firefox, it give me a blank page and no error.\n\nwhat i am trying to do is to access the web service from java using the wsimport tool, but i am unable to authenticate. i have already created a folder in ~/.metro/auth and put the following line in there:\n\nhttp://userfoobar:passforbar@192.168.0.170:7047//dynamicsnav71/ws/cronus%20ag/page/pagewithcapitalization\n\n\nand i am trying to access the web page with:\n\nwsimport -d generated -s sources http://@192.168.0.170:7047/dynamicsnav71/ws/cronus%20ag/page/pagewithcapitalization\n\n\ni always get the error:\n\n[error] server returned http response code: 401 for url: http://@19
# ...

# %%
df.shape
# Out:
# (100000, 7)

# %%
df.head()
# Out:
#    Unnamed: 0        Id  Score  \
# 0           0  12395950      2
# 1           1  22426350      0
# 2           2  19842160      0
# 3           3  22953000      0
# 4           4  35528560      0
#
#                                                Title  \
# 0       Calling Twain driver from 64 bit application
# 1  Why does variable in struct instance change af...
# 2  dynamically creating text fields lands up in d...
# 3      Javascript in PHP/HTML hiding Div not working
# 4  Design a compareTo that can sort in ascending ...
#
#                                                 Body                    Tags  \
# 0  <p>I need to call TWAIN API from .NET (C#) app...           c# .net twain
# 1  <p>This is really weird.</p>\n\n<p>I have a st...                c struct
# 2  <p>I'm having issues with the below code,\nwhe...  javascript jquery html
# 3  <p>I am new to coding so be gentle.  I am buil...     javascript php html
# ...

# %%
df.text = df.text.apply(lambda x: x.replace('"','').replace('\n','').replace('\t',''))

# %%
df['text'][10]
# Out:
# 'i am trying to access a dynamics nav 2013 r2 web service from java. the web service is running and when i enter the url in the internet explorer, i can see the wsdl but first i am prompted for username and password. on wireshark i can see that it uses authentication based on ntlm. sofar i was only able to open the wsdl from internet explorer, when i open it on firefox, it give me a blank page and no error.what i am trying to do is to access the web service from java using the wsimport tool, but i am unable to authenticate. i have already created a folder in ~/.metro/auth and put the following line in there:http://userfoobar:passforbar@192.168.0.170:7047//dynamicsnav71/ws/cronus%20ag/page/pagewithcapitalizationand i am trying to access the web page with:wsimport -d generated -s sources http://@192.168.0.170:7047/dynamicsnav71/ws/cronus%20ag/page/pagewithcapitalizationi always get the error:[error] server returned http response code: 401 for url: http://@192.168.0.170:7047/dynamicsnav
# ...

# %%
re.sub('[a-z\[\]]+://[^ ]+',Empty,df['text'][10])
# Out:
# 'i am trying to access a dynamics nav 2013 r2 web service from java. the web service is running and when i enter the url in the internet explorer, i can see the wsdl but first i am prompted for username and password. on wireshark i can see that it uses authentication based on ntlm. sofar i was only able to open the wsdl from internet explorer, when i open it on firefox, it give me a blank page and no error.what i am trying to do is to access the web service from java using the wsimport tool, but i am unable to authenticate. i have already created a folder in ~/.metro/auth and put the following line in there: i am trying to access the web page with:wsimport -d generated -s sources  always get the error:[error] server returned http response code: 401 for url:    needs authorization, please provide authorization file with read access at /home/user/.metro/auth or use -xauthfile to give the authorization file and on each line provide authorization information using this format :  have tri
# ...

# %%
def clean_links(text): #removes the hyperlinks
    if not isinstance(text,str):
        return text
    return re.sub('[a-z\[\]]+://[^ ]+',Empty,text)

# %%
df['text'] = df['text'].apply(clean_links).str.lower()

# %%
df.head()
# Out:
#    Unnamed: 0        Id  Score  \
# 0           0  12395950      2
# 1           1  22426350      0
# 2           2  19842160      0
# 3           3  22953000      0
# 4           4  35528560      0
#
#                                                Title  \
# 0       Calling Twain driver from 64 bit application
# 1  Why does variable in struct instance change af...
# 2  dynamically creating text fields lands up in d...
# 3      Javascript in PHP/HTML hiding Div not working
# 4  Design a compareTo that can sort in ascending ...
#
#                                                 Body                    Tags  \
# 0  <p>I need to call TWAIN API from .NET (C#) app...           c# .net twain
# 1  <p>This is really weird.</p>\n\n<p>I have a st...                c struct
# 2  <p>I'm having issues with the below code,\nwhe...  javascript jquery html
# 3  <p>I am new to coding so be gentle.  I am buil...     javascript php html
# ...

# %%
df.text = df.text.apply(lambda x: x.replace(':',''))

# %%
df['text'][10]
# Out:
# 'i am trying to access a dynamics nav 2013 r2 web service from java. the web service is running and when i enter the url in the internet explorer, i can see the wsdl but first i am prompted for username and password. on wireshark i can see that it uses authentication based on ntlm. sofar i was only able to open the wsdl from internet explorer, when i open it on firefox, it give me a blank page and no error.what i am trying to do is to access the web service from java using the wsimport tool, but i am unable to authenticate. i have already created a folder in ~/.metro/auth and put the following line in there i am trying to access the web page withwsimport -d generated -s sources  always get the error[error] server returned http response code 401 for url    needs authorization, please provide authorization file with read access at /home/user/.metro/auth or use -xauthfile to give the authorization file and on each line provide authorization information using this format   have tried thi
# ...

# %%
#now we will have to find out the number of tags
df['Tags'].nunique()
# Out:
# 70032

# %%
df['Tags'][10].strip().split(' ')
# Out:
# ['java', 'microsoft-dynamics', 'dynamics-nav', 'dynamics-nav-2013']

# %%
count_dic = dict()
#finding out the number of occurrences of each tag

n = df.shape[0]
for i in range(n):
    for tag in str(df['Tags'][i]).strip().split(' '):
        if tag in count_dic:
            count_dic[tag]+=1
        else:
            count_dic[tag] = 1

# %%
count_dic
# Out:
# {'c#': 7999,
#  '.net': 1943,
#  'twain': 7,
#  'c': 1785,
#  'struct': 106,
#  'javascript': 9696,
#  'jquery': 6283,
#  'html': 4790,
#  'php': 7829,
#  'java': 9113,
#  'c++': 3682,
#  'object': 218,
#  'makefile': 139,
#  'mysql': 3509,
#  'web-services': 436,
#  'java-me': 61,
#  'wsdl': 73,
#  'replace': 120,
#  'opencv': 275,
#  'matrix': 164,
#  'dimensionality-reduction': 3,
#  'ajax': 1261,
#  'autocomplete': 87,
#  'autosuggest': 3,
#  'microsoft-dynamics': 9,
#  'dynamics-nav': 2,
#  'dynamics-nav-2013': 1,
#  'ios': 3677,
#  'xamarin.ios': 76,
#  'uitextfield': 53,
#  'asp.net': 2358,
#  'vb.net': 825,
#  'blob': 23,
#  'android': 7230,
#  'python': 5133,
#  'list': 424,
#  'pandas': 262,
#  'c#-4.0': 180,
#  'solr': 122,
#  'web-crawler': 45,
#  'mkmapview': 36,
#  'area': 6,
#  'django': 1029,
#  'django-admin': 55,
#  'intellij-idea': 163,
#  'clipboard': 12,
#  'presentation': 3,
#  'sorting': 321,
#  'collections': 110,
#  'variables': 260,
#  'serial-port': 60,
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

word_cloud = WordCloud(height=200,width=300,background_color='black').generate(str(count_dic))
plt.imshow(word_cloud)
plt.show()

# %%
#removing the punctuation mark
df.text = df.text.apply(lambda x: x.replace('.','').replace(',','').replace('?',''))
type(count_dic.keys())
count_dic
# Out:
# {'c#': 7999,
#  '.net': 1943,
#  'twain': 7,
#  'c': 1785,
#  'struct': 106,
#  'javascript': 9696,
#  'jquery': 6283,
#  'html': 4790,
#  'php': 7829,
#  'java': 9113,
#  'c++': 3682,
#  'object': 218,
#  'makefile': 139,
#  'mysql': 3509,
#  'web-services': 436,
#  'java-me': 61,
#  'wsdl': 73,
#  'replace': 120,
#  'opencv': 275,
#  'matrix': 164,
#  'dimensionality-reduction': 3,
#  'ajax': 1261,
#  'autocomplete': 87,
#  'autosuggest': 3,
#  'microsoft-dynamics': 9,
#  'dynamics-nav': 2,
#  'dynamics-nav-2013': 1,
#  'ios': 3677,
#  'xamarin.ios': 76,
#  'uitextfield': 53,
#  'asp.net': 2358,
#  'vb.net': 825,
#  'blob': 23,
#  'android': 7230,
#  'python': 5133,
#  'list': 424,
#  'pandas': 262,
#  'c#-4.0': 180,
#  'solr': 122,
#  'web-crawler': 45,
#  'mkmapview': 36,
#  'area': 6,
#  'django': 1029,
#  'django-admin': 55,
#  'intellij-idea': 163,
#  'clipboard': 12,
#  'presentation': 3,
#  'sorting': 321,
#  'collections': 110,
#  'variables': 260,
#  'serial-port': 60,
# ...

# %%
#making the reference dictionary
dic = dict()
reverse_dic = dict()

n = 0

for tag in count_dic.keys():
    if tag not in dic:
        n = len(dic)
        dic[tag] = n
        reverse_dic[n] = tag

# %%
dic
# Out:
# {'c#': 0,
#  '.net': 1,
#  'twain': 2,
#  'c': 3,
#  'struct': 4,
#  'javascript': 5,
#  'jquery': 6,
#  'html': 7,
#  'php': 8,
#  'java': 9,
#  'c++': 10,
#  'object': 11,
#  'makefile': 12,
#  'mysql': 13,
#  'web-services': 14,
#  'java-me': 15,
#  'wsdl': 16,
#  'replace': 17,
#  'opencv': 18,
#  'matrix': 19,
#  'dimensionality-reduction': 20,
#  'ajax': 21,
#  'autocomplete': 22,
#  'autosuggest': 23,
#  'microsoft-dynamics': 24,
#  'dynamics-nav': 25,
#  'dynamics-nav-2013': 26,
#  'ios': 27,
#  'xamarin.ios': 28,
#  'uitextfield': 29,
#  'asp.net': 30,
#  'vb.net': 31,
#  'blob': 32,
#  'android': 33,
#  'python': 34,
#  'list': 35,
#  'pandas': 36,
#  'c#-4.0': 37,
#  'solr': 38,
#  'web-crawler': 39,
#  'mkmapview': 40,
#  'area': 41,
#  'django': 42,
#  'django-admin': 43,
#  'intellij-idea': 44,
#  'clipboard': 45,
#  'presentation': 46,
#  'sorting': 47,
#  'collections': 48,
#  'variables': 49,
#  'serial-port': 50,
#  'port': 51,
#  'pyserial': 52,
#  'node.js': 53,
# ...

# %%
df.drop(columns=['Id','Score','Body'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0       Calling Twain driver from 64 bit application
# 1           1  Why does variable in struct instance change af...
# 2           2  dynamically creating text fields lands up in d...
# 3           3      Javascript in PHP/HTML hiding Div not working
# 4           4  Design a compareTo that can sort in ascending ...
#
#                      Tags                                               text
# 0           c# .net twain  i need to call twain api from net (c#) applica...
# 1                c struct  this is really weirdi have a struct with int v...
# 2  javascript jquery html  i'm having issues with the below codewhen i cl...
# 3     javascript php html  i am new to coding so be gentle  i am building...
# 4                    java  i have a class states that is an object that c...

# %%
dic_len = len(dic)
print('Total no of tags: ',dic_len)
# Out:
# Total no of tags:  17998

# %%
df.Title = df.Title.apply(lambda x: x.replace(',','').replace('/',' ').replace('.','').replace(',','').replace('?','')).str.lower()

# %%
df['Title'][3]
df.text = df.text.apply(lambda x: x.replace('&lt',' ').replace('(',' ').replace(')',' ').replace(';',' ').replace('&gt',' ').replace('/',' '))

# %%
vocabulary = dict()

n = df.shape[0]
m = -1
for i in range(n):
    if len((str(df['text'][i])+' '+str(df['Title'][i])).strip().split(' '))>m:
        m = len((str(df['text'][i])+' '+str(df['Title'][i])).strip().split(' '))
    for word in (str(df['text'][i])+' '+str(df['Title'][i])).strip().split(' '):
        if word not in s and word not in vocabulary:
            vocabulary[word] = len(vocabulary)+1
print("Total vocabulary strength: ",len(vocabulary))
print("Length of longest question: ",m)

# %%
import nltk
from nltk.corpus import stopwords

# %%
s = set(stopwords.words('english'))
s
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
tag_num = len(count_dic)
vocab_size = len(vocabulary)
def tokenize(text):
    l = []
    for word in text.strip().split(' '):
        if word not in s:
            l.append(vocabulary[word])
    while len(l)<m:
        l.append(0)
    return np.array(l,dtype=np.float32)

def tokenize_tags(text):
    l = np.zeros((1,dic_len),dtype=np.float32)
    for word in text.strip().split(' '):
        l[0,dic[word]] = 1.0
    return l

class Predictor:
    def __init__(self):
        self.x = tf.placeholder(dtype=tf.float32,shape=[None,m,1])
        self.y = tf.placeholder(dtype=tf.float32,shape=[None,tag_num])
        self.n_hidden = 256
        self.weights = {'out': tf.Variable(tf.random_normal([self.n_hidden,dic_len]))}
        self.biases = {'out': tf.Variable(tf.random_normal([dic_len]))}
        self.rnn1 = tf.nn.rnn_cell.LSTMCell(num_units=self.n_hidden)
        self.rnn2 = tf.nn.rnn_cell.LSTMCell(num_units=self.n_hidden)
        self.rnn3 = tf.nn.rnn_cell.MultiRNNCell([self.rnn1,self.rnn2])
        self.y_1 = self.predict(self.x)
        self.loss = tf.reduce_mean(tf.square(tf.nn.softmax_cross_entropy_with_logits(logits=self.y_1,labels=self.y)))
        self.opt = tf.train.AdamOptimizer(learning_rate=0.001).minimize(self.loss)
        #self.outputs,self.states = tf.nn.static_rnn(self.rnn3,self.x,dtype=tf.float32)
    def predict(self,arr):
        arr = tf.reshape(arr,[-1,m])
        arr = tf.split(arr,m,1)
        output,states = tf.nn.static_rnn(self.rnn3,arr,dtype=tf.float32)
        return tf.matmul(output[-1],self.weights['out'])+self.biases['out']
    def train(self):
        df1 = df.sample(n=10000,random_state=1)
        with tf.Session() as ss:
            ss.run(tf.global_variables_initializer())
            losses = []
            for i in range(10000):
                input_x = tokenize(str(df['text'][i]))
                input_y = tokenize_tags(str(df['Tags'][i]))
                _,cost = ss.run([self.opt,self.loss],feed_dict={self.x:input_x,self.y:input_y})
                if(i%1000==0):
                    print("cost = ",cost)
                if(i%100==0):
                    losses.append(cost)
        plt.plot(losses)
        plt.show()

# %%
# Out:
# (4, 3245)
